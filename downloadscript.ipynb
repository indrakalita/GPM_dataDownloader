# %% [markdown]
# # Manual for Downloading GPM Data
# [More info: https://github.com/nasa/gesdisc-tutorials/blob/main/notebooks/How_to_Access_GES_DISC_Data_Using_Python.ipynb]
#
# Accessing and downloading data from GES DISC requires an Earthdata account. Registration is free and easy:
#
# ## Step 1: Create an Earthdata Account
# Follow this link to create your Earthdata account: [Create Earthdata Account](https://disc.gsfc.nasa.gov/information/documents?title=Data%20Access#mac_linux_wget)
#
# ## Step 2: Link GES DISC with Your Account
# Link your Earthdata account with GES DISC using this link: [Link GES DISC](https://disc.gsfc.nasa.gov/earthdata-login)
#
# ## Step 3: Access GPM Daily Data
# For daily data, visit: [GPM Daily Data](https://disc.gsfc.nasa.gov/datasets/GPM_3IMERGDF_07/summary?keywords=%22IMERG%20final%22)
#
# ### a) Click on "Subset/Get Data"
# - Navigate to the "Subset/Get Data" option.
#
# ### b) Select Download Method
# - Choose the download method as **"Get file Subsets using the GES DISC subsetter."**
#
# ### c) Refine the Region
# - In the method option, refine the region using the coordinates of the required Area of Interest (AOI).
#   - For Ghana: **Refine Region:** `-3.8, 4.3, 1.8, 11.6`
#
# ### d) Select Variables
# - Select all the required variables for your analysis.
#
# ### e) Regrid
# - Set **Regrid:** Keep the original grid.
#
# ### f) Output Format
# - Set **Output format:** netCDF.
#
# ### g) Get Data
# - Click on **Get Data** to download the data file (e.g., `downloadLink.txt`).
#
# ## Step 4: Downloading Data Using wget
# Use the following `wget` command to download the data files listed in `downloadLink.txt`:
#
# ```bash
# wget --user=<username> --password=<password> --content-disposition -i /path/to/downloadedfile/downloadLink.txt -P /save/folder/location/

# %%
# !wget --user=indrabu --password='Adipall123# ' --content-disposition -i downloadLink.txt -P ./data/
# Out:
# --2025-02-25 16:26:38--  https://arthurhou.pps.eosdis.nasa.gov/Documents/IMERG_V07_ATBD_final.pdf
# Resolving arthurhou.pps.eosdis.nasa.gov (arthurhou.pps.eosdis.nasa.gov)... 198.118.195.100, 2001:4d0:241a:40a0::64
# Connecting to arthurhou.pps.eosdis.nasa.gov (arthurhou.pps.eosdis.nasa.gov)|198.118.195.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3526898 (3.4M) [application/pdf]
# Saving to: ‘./data/IMERG_V07_ATBD_final.pdf’
#
# IMERG_V07_ATBD_fina 100%[===================>]   3.36M  --.-KB/s    in 0.1s
#
# 2025-02-25 16:26:38 (27.2 MB/s) - ‘./data/IMERG_V07_ATBD_final.pdf’ saved [3526898/3526898]
#
# --2025-02-25 16:26:38--  https://gpm1.gesdisc.eosdis.nasa.gov/data/GPM_L3/doc/README.GPM.pdf
# Resolving gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)... 198.118.197.50, 2001:4d0:241a:4041::50
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 396395 (387K) [application/pdf]
# Saving to: ‘./data/README.GPM.pdf’
#
# README.GPM.pdf      100%[===================>] 387.10K  --.-KB/s    in 0.06s
#
# 2025-02-25 16:26:38 (6.24 MB/s) - ‘./data/README.GPM.pdf’ saved [396395/396395]
#
# --2025-02-25 16:26:38--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980101-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980101-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# The name is too long, 309 chars total.
# Trying to shorten...
# New name is HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980101-S000000-E235959.V07B.nc4&BBOX=4.3,-3.8,11.6,1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSIO.
# Location: https://urs.earthdata.nasa.gov/oauth/authorize/?scope=uid&app_type=401&client_id=e2WVk8Pw6weeLUKZYOxvTQ&response_type=code&redirect_uri=https%3A%2F%2Fgpm1.gesdisc.eosdis.nasa.gov%2Fdata-redirect&state=... [following]
# --2025-02-25 16:26:38--  https://urs.earthdata.nasa.gov/oauth/authorize/?scope=uid&app_type=401&client_id=e2WVk8Pw6weeLUKZYOxvTQ&response_type=code&redirect_uri=https%3A%2F%2Fgpm1.gesdisc.eosdis.nasa.gov%2Fdata-redirect&state=...
# Resolving urs.earthdata.nasa.gov (urs.earthdata.nasa.gov)... 198.118.243.33, 2001:4d0:241a:4081::89
# connected. to urs.earthdata.nasa.gov (urs.earthdata.nasa.gov)|198.118.243.33|:443...
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Please enter your Earthdata Login credentials. If you do not have a Earthdata Login, create one at https://urs.earthdata.nasa.gov//users/new"
# Reusing existing connection to urs.earthdata.nasa.gov:443.
# 302 Foundest sent, awaiting response...
# The name is too long, 649 chars total.
# Trying to shorten...
# New name is index.html?scope=uid&app_type=401&client_id=e2WVk8Pw6weeLUKZYOxvTQ&response_type=code&redirect_uri=https:%2F%2Fgpm1.gesdisc.eosdis.nasa.gov%2Fdata-redirect&state=aHR0cHM6Ly9ncG0xLmdlc2Rpc2MuZW9zZGlzLm5hc2EuZ292L2RhYWMtYmluL09URi9IVFRQX3.
# Location: https://gpm1.gesdisc.eosdis.nasa.gov/data-redirect?code=9vIyVm0KN-xXjGdUREF0z-cISym5GBa-Op_uaJzlMc12e6UoaBamVNazvVlrVl362GFcp7yz7JY_pyro0wE7jBkCdMqRm-lcYYQdFt2QLjuNAx8vqM0Wnevu&state=... [following]
# --2025-02-25 16:26:38--  https://gpm1.gesdisc.eosdis.nasa.gov/data-redirect?code=9vIyVm0KN-xXjGdUREF0z-cISym5GBa-Op_uaJzlMc12e6UoaBamVNazvVlrVl362GFcp7yz7JY_pyro0wE7jBkCdMqRm-lcYYQdFt2QLjuNAx8vqM0Wnevu&state=...
# connected. to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443...
# HTTP request sent, awaiting response... 302 Found
# The name is too long, 633 chars total.
# Trying to shorten...
# New name is data-redirect?code=9vIyVm0KN-xXjGdUREF0z-cISym5GBa-Op_uaJzlMc12e6UoaBamVNazvVlrVl362GFcp7yz7JY_pyro0wE7jBkCdMqRm-lcYYQdFt2QLjuNAx8vqM0Wnevu&state=aHR0cHM6Ly9ncG0xLmdlc2Rpc2MuZW9zZGlzLm5hc2EuZ292L2RhYWMtYmluL09URi9IVFRQX3NlcnZpY2VzLmNnaT.
# Location: https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980101-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980101-S000000-E235959.V07B.nc4.SUB.nc4 [following]
# --2025-02-25 16:26:39--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980101-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980101-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 73590 (72K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980101-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  71.87K  --.-KB/s    in 0.05s
#
# 2025-02-25 16:26:41 (1.51 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980101-S000000-E235959.V07B.nc4.SUB.nc4’ saved [73590/73590]
#
# --2025-02-25 16:26:41--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980102-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980102-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72669 (71K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980102-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  70.97K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:26:43 (2.35 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980102-S000000-E235959.V07B.nc4.SUB.nc4’ saved [72669/72669]
#
# --2025-02-25 16:26:43--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980103-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980103-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 74429 (73K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980103-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  72.68K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:26:46 (2.39 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980103-S000000-E235959.V07B.nc4.SUB.nc4’ saved [74429/74429]
#
# --2025-02-25 16:26:46--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980104-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980104-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68666 (67K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980104-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  67.06K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:26:48 (2.22 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980104-S000000-E235959.V07B.nc4.SUB.nc4’ saved [68666/68666]
#
# --2025-02-25 16:26:48--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980105-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980105-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 80290 (78K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980105-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  78.41K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:26:50 (2.56 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980105-S000000-E235959.V07B.nc4.SUB.nc4’ saved [80290/80290]
#
# --2025-02-25 16:26:50--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980106-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980106-S000000-E235959.V07B.nc4.SUB.nc4
# connected. to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443...
# HTTP request sent, awaiting response... 200 OK
# Length: 78000 (76K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980106-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  76.17K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:26:51 (2.51 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980106-S000000-E235959.V07B.nc4.SUB.nc4’ saved [78000/78000]
#
# --2025-02-25 16:26:51--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980107-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980107-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72140 (70K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980107-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  70.45K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:26:54 (2.31 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980107-S000000-E235959.V07B.nc4.SUB.nc4’ saved [72140/72140]
#
# --2025-02-25 16:26:54--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980108-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980108-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71298 (70K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980108-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  69.63K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:26:56 (2.28 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980108-S000000-E235959.V07B.nc4.SUB.nc4’ saved [71298/71298]
#
# --2025-02-25 16:26:56--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980109-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980109-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71662 (70K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980109-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  69.98K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:26:59 (2.29 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980109-S000000-E235959.V07B.nc4.SUB.nc4’ saved [71662/71662]
#
# --2025-02-25 16:26:59--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980110-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980110-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69309 (68K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980110-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  67.68K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:00 (2.27 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980110-S000000-E235959.V07B.nc4.SUB.nc4’ saved [69309/69309]
#
# --2025-02-25 16:27:00--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980111-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980111-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66591 (65K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980111-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  65.03K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:03 (2.16 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980111-S000000-E235959.V07B.nc4.SUB.nc4’ saved [66591/66591]
#
# --2025-02-25 16:27:03--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980112-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980112-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68196 (67K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980112-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  66.60K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:05 (2.19 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980112-S000000-E235959.V07B.nc4.SUB.nc4’ saved [68196/68196]
#
# --2025-02-25 16:27:05--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980113-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980113-S000000-E235959.V07B.nc4.SUB.nc4
# connected. to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443...
# 200 OKequest sent, awaiting response...
# Length: 75651 (74K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980113-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  73.88K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:07 (2.43 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980113-S000000-E235959.V07B.nc4.SUB.nc4’ saved [75651/75651]
#
# --2025-02-25 16:27:07--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980114-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980114-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76538 (75K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980114-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  74.74K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:09 (2.45 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980114-S000000-E235959.V07B.nc4.SUB.nc4’ saved [76538/76538]
#
# --2025-02-25 16:27:09--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980115-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980115-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69611 (68K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980115-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  67.98K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:10 (2.25 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980115-S000000-E235959.V07B.nc4.SUB.nc4’ saved [69611/69611]
#
# --2025-02-25 16:27:10--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980116-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980116-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68170 (67K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980116-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  66.57K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:13 (2.21 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980116-S000000-E235959.V07B.nc4.SUB.nc4’ saved [68170/68170]
#
# --2025-02-25 16:27:13--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980117-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980117-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68404 (67K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980117-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  66.80K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:15 (2.20 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980117-S000000-E235959.V07B.nc4.SUB.nc4’ saved [68404/68404]
#
# --2025-02-25 16:27:15--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980118-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980118-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66779 (65K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980118-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  65.21K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:18 (2.16 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980118-S000000-E235959.V07B.nc4.SUB.nc4’ saved [66779/66779]
#
# --2025-02-25 16:27:18--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980119-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980119-S000000-E235959.V07B.nc4.SUB.nc4
# connected. to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443...
# HTTP request sent, awaiting response... 200 OK
# Length: 67764 (66K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980119-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  66.18K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:19 (2.18 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980119-S000000-E235959.V07B.nc4.SUB.nc4’ saved [67764/67764]
#
# --2025-02-25 16:27:19--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980120-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980120-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69991 (68K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980120-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  68.35K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:21 (2.28 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980120-S000000-E235959.V07B.nc4.SUB.nc4’ saved [69991/69991]
#
# --2025-02-25 16:27:21--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980121-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980121-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69406 (68K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980121-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  67.78K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:24 (2.24 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980121-S000000-E235959.V07B.nc4.SUB.nc4’ saved [69406/69406]
#
# --2025-02-25 16:27:24--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980122-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980122-S000000-E235959.V07B.nc4.SUB.nc4
# connected. to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443...
# 200 OKequest sent, awaiting response...
# Length: 67808 (66K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980122-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  66.22K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:25 (2.14 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980122-S000000-E235959.V07B.nc4.SUB.nc4’ saved [67808/67808]
#
# --2025-02-25 16:27:25--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980123-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980123-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 67278 (66K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980123-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  65.70K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:28 (2.11 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980123-S000000-E235959.V07B.nc4.SUB.nc4’ saved [67278/67278]
#
# --2025-02-25 16:27:28--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980124-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980124-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72653 (71K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980124-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  70.95K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:30 (2.35 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980124-S000000-E235959.V07B.nc4.SUB.nc4’ saved [72653/72653]
#
# --2025-02-25 16:27:30--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980125-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980125-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66153 (65K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980125-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  64.60K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:33 (2.17 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980125-S000000-E235959.V07B.nc4.SUB.nc4’ saved [66153/66153]
#
# --2025-02-25 16:27:33--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980126-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980126-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 67974 (66K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980126-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  66.38K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:35 (2.18 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980126-S000000-E235959.V07B.nc4.SUB.nc4’ saved [67974/67974]
#
# --2025-02-25 16:27:35--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980127-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980127-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72393 (71K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980127-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  70.70K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:38 (2.34 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980127-S000000-E235959.V07B.nc4.SUB.nc4’ saved [72393/72393]
#
# --2025-02-25 16:27:38--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980128-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980128-S000000-E235959.V07B.nc4.SUB.nc4
# connected. to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443...
# HTTP request sent, awaiting response... 200 OK
# Length: 85989 (84K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980128-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  83.97K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:40 (2.74 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980128-S000000-E235959.V07B.nc4.SUB.nc4’ saved [85989/85989]
#
# --2025-02-25 16:27:40--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980129-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980129-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85278 (83K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980129-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  83.28K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:42 (2.74 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980129-S000000-E235959.V07B.nc4.SUB.nc4’ saved [85278/85278]
#
# --2025-02-25 16:27:42--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980130-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980130-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 95720 (93K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980130-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  93.48K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:45 (3.08 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980130-S000000-E235959.V07B.nc4.SUB.nc4’ saved [95720/95720]
#
# --2025-02-25 16:27:45--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F01%2F3B-DAY.MS.MRG.3IMERG.19980131-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980131-S000000-E235959.V07B.nc4.SUB.nc4
# connected. to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443...
# HTTP request sent, awaiting response... 200 OK
# Length: 82024 (80K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980131-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  80.10K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:46 (2.63 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980131-S000000-E235959.V07B.nc4.SUB.nc4’ saved [82024/82024]
#
# --2025-02-25 16:27:46--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F02%2F3B-DAY.MS.MRG.3IMERG.19980201-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980201-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 86893 (85K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980201-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  84.86K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:49 (2.80 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980201-S000000-E235959.V07B.nc4.SUB.nc4’ saved [86893/86893]
#
# --2025-02-25 16:27:49--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F02%2F3B-DAY.MS.MRG.3IMERG.19980202-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980202-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 81084 (79K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980202-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  79.18K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:50 (2.58 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980202-S000000-E235959.V07B.nc4.SUB.nc4’ saved [81084/81084]
#
# --2025-02-25 16:27:50--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F02%2F3B-DAY.MS.MRG.3IMERG.19980203-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980203-S000000-E235959.V07B.nc4.SUB.nc4
# connected. to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443...
# 200 OKequest sent, awaiting response...
# Length: 70221 (69K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980203-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  68.58K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:53 (2.26 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980203-S000000-E235959.V07B.nc4.SUB.nc4’ saved [70221/70221]
#
# --2025-02-25 16:27:53--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F02%2F3B-DAY.MS.MRG.3IMERG.19980204-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980204-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 73484 (72K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980204-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  71.76K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:54 (2.37 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980204-S000000-E235959.V07B.nc4.SUB.nc4’ saved [73484/73484]
#
# --2025-02-25 16:27:54--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F02%2F3B-DAY.MS.MRG.3IMERG.19980205-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980205-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72009 (70K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980205-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  70.32K  --.-KB/s    in 0.02s
#
# 2025-02-25 16:27:57 (3.64 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980205-S000000-E235959.V07B.nc4.SUB.nc4’ saved [72009/72009]
#
# --2025-02-25 16:27:57--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F02%2F3B-DAY.MS.MRG.3IMERG.19980206-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980206-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 79951 (78K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980206-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  78.08K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:27:59 (2.59 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980206-S000000-E235959.V07B.nc4.SUB.nc4’ saved [79951/79951]
#
# --2025-02-25 16:27:59--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F02%2F3B-DAY.MS.MRG.3IMERG.19980207-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980207-S000000-E235959.V07B.nc4.SUB.nc4
# connected. to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443...
# HTTP request sent, awaiting response... 200 OK
# Length: 74169 (72K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980207-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  72.43K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:28:00 (2.42 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980207-S000000-E235959.V07B.nc4.SUB.nc4’ saved [74169/74169]
#
# --2025-02-25 16:28:00--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F02%2F3B-DAY.MS.MRG.3IMERG.19980208-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980208-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 77106 (75K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980208-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  75.30K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:28:03 (2.46 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980208-S000000-E235959.V07B.nc4.SUB.nc4’ saved [77106/77106]
#
# --2025-02-25 16:28:03--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F02%2F3B-DAY.MS.MRG.3IMERG.19980209-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980209-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 91610 (89K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980209-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  89.46K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:28:05 (2.98 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980209-S000000-E235959.V07B.nc4.SUB.nc4’ saved [91610/91610]
#
# --2025-02-25 16:28:05--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F02%2F3B-DAY.MS.MRG.3IMERG.19980210-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980210-S000000-E235959.V07B.nc4.SUB.nc4
# connected. to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443...
# HTTP request sent, awaiting response... 200 OK
# Length: 90955 (89K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980210-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  88.82K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:28:08 (2.94 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980210-S000000-E235959.V07B.nc4.SUB.nc4’ saved [90955/90955]
#
# --2025-02-25 16:28:08--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F02%2F3B-DAY.MS.MRG.3IMERG.19980211-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980211-S000000-E235959.V07B.nc4.SUB.nc4
# connected. to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443...
# HTTP request sent, awaiting response... 200 OK
# Length: 97228 (95K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980211-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  94.95K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:28:09 (3.14 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980211-S000000-E235959.V07B.nc4.SUB.nc4’ saved [97228/97228]
#
# --2025-02-25 16:28:09--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F02%2F3B-DAY.MS.MRG.3IMERG.19980212-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980212-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 104712 (102K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980212-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>] 102.26K  --.-KB/s    in 0.04s
#
# 2025-02-25 16:28:12 (2.24 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980212-S000000-E235959.V07B.nc4.SUB.nc4’ saved [104712/104712]
#
# --2025-02-25 16:28:12--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F02%2F3B-DAY.MS.MRG.3IMERG.19980213-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980213-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88419 (86K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980213-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  86.35K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:28:14 (2.86 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980213-S000000-E235959.V07B.nc4.SUB.nc4’ saved [88419/88419]
#
# --2025-02-25 16:28:14--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F02%2F3B-DAY.MS.MRG.3IMERG.19980214-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980214-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 67361 (66K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980214-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  65.78K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:28:17 (2.19 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980214-S000000-E235959.V07B.nc4.SUB.nc4’ saved [67361/67361]
#
# --2025-02-25 16:28:17--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F02%2F3B-DAY.MS.MRG.3IMERG.19980215-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980215-S000000-E235959.V07B.nc4.SUB.nc4
# connected. to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443...
# HTTP request sent, awaiting response... 200 OK
# Length: 66153 (65K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980215-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  64.60K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:28:19 (2.13 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980215-S000000-E235959.V07B.nc4.SUB.nc4’ saved [66153/66153]
#
# --2025-02-25 16:28:19--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F02%2F3B-DAY.MS.MRG.3IMERG.19980216-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980216-S000000-E235959.V07B.nc4.SUB.nc4
# connected. to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443...
# HTTP request sent, awaiting response... 200 OK
# Length: 66936 (65K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980216-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  65.37K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:28:21 (2.16 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980216-S000000-E235959.V07B.nc4.SUB.nc4’ saved [66936/66936]
#
# --2025-02-25 16:28:21--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F02%2F3B-DAY.MS.MRG.3IMERG.19980217-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980217-S000000-E235959.V07B.nc4.SUB.nc4
# connected. to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443...
# HTTP request sent, awaiting response... 200 OK
# Length: 70043 (68K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980217-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  68.40K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:28:24 (2.25 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980217-S000000-E235959.V07B.nc4.SUB.nc4’ saved [70043/70043]
#
# --2025-02-25 16:28:24--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F02%2F3B-DAY.MS.MRG.3IMERG.19980218-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980218-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66768 (65K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980218-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  65.20K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:28:26 (2.19 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980218-S000000-E235959.V07B.nc4.SUB.nc4’ saved [66768/66768]
#
# ...
# HTTP request sent, awaiting response... 200 OK
# Length: 95987 (94K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980501-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  93.74K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:31:02 (3.07 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980501-S000000-E235959.V07B.nc4.SUB.nc4’ saved [95987/95987]
#
# --2025-02-25 16:31:02--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F05%2F3B-DAY.MS.MRG.3IMERG.19980502-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980502-S000000-E235959.V07B.nc4.SUB.nc4
# connected. to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443...
# HTTP request sent, awaiting response... 200 OK
# Length: 103407 (101K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980502-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>] 100.98K  --.-KB/s    in 0.04s
#
# 2025-02-25 16:31:05 (2.24 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980502-S000000-E235959.V07B.nc4.SUB.nc4’ saved [103407/103407]
#
# --2025-02-25 16:31:05--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F05%2F3B-DAY.MS.MRG.3IMERG.19980503-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980503-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 86414 (84K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980503-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  84.39K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:31:07 (2.80 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980503-S000000-E235959.V07B.nc4.SUB.nc4’ saved [86414/86414]
#
# --2025-02-25 16:31:07--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F05%2F3B-DAY.MS.MRG.3IMERG.19980504-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980504-S000000-E235959.V07B.nc4.SUB.nc4
# connected. to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443...
# HTTP request sent, awaiting response... 200 OK
# Length: 103789 (101K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980504-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>] 101.36K  --.-KB/s    in 0.04s
#
# 2025-02-25 16:31:10 (2.23 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980504-S000000-E235959.V07B.nc4.SUB.nc4’ saved [103789/103789]
#
# --2025-02-25 16:31:10--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F05%2F3B-DAY.MS.MRG.3IMERG.19980505-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980505-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 94999 (93K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980505-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  92.77K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:31:12 (3.05 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980505-S000000-E235959.V07B.nc4.SUB.nc4’ saved [94999/94999]
#
# --2025-02-25 16:31:12--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F05%2F3B-DAY.MS.MRG.3IMERG.19980506-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980506-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88468 (86K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980506-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  86.39K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:31:14 (2.87 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980506-S000000-E235959.V07B.nc4.SUB.nc4’ saved [88468/88468]
#
# --2025-02-25 16:31:14--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F05%2F3B-DAY.MS.MRG.3IMERG.19980507-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980507-S000000-E235959.V07B.nc4.SUB.nc4
# connected. to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443...
# HTTP request sent, awaiting response... 200 OK
# Length: 102010 (100K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980507-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  99.62K  --.-KB/s    in 0.04s
#
# 2025-02-25 16:31:17 (2.19 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980507-S000000-E235959.V07B.nc4.SUB.nc4’ saved [102010/102010]
#
# --2025-02-25 16:31:17--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F05%2F3B-DAY.MS.MRG.3IMERG.19980508-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980508-S000000-E235959.V07B.nc4.SUB.nc4
# connected. to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443...
# HTTP request sent, awaiting response... 200 OK
# Length: 86627 (85K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980508-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  84.60K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:31:19 (2.73 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980508-S000000-E235959.V07B.nc4.SUB.nc4’ saved [86627/86627]
#
# --2025-02-25 16:31:19--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F05%2F3B-DAY.MS.MRG.3IMERG.19980509-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980509-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84272 (82K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980509-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  82.30K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:31:22 (2.69 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980509-S000000-E235959.V07B.nc4.SUB.nc4’ saved [84272/84272]
#
# --2025-02-25 16:31:22--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F05%2F3B-DAY.MS.MRG.3IMERG.19980510-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980510-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 97886 (96K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980510-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  95.59K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:31:23 (3.13 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980510-S000000-E235959.V07B.nc4.SUB.nc4’ saved [97886/97886]
#
# --2025-02-25 16:31:23--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F05%2F3B-DAY.MS.MRG.3IMERG.19980511-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980511-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 92807 (91K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980511-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  90.63K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:31:26 (2.94 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980511-S000000-E235959.V07B.nc4.SUB.nc4’ saved [92807/92807]
#
# --2025-02-25 16:31:26--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F05%2F3B-DAY.MS.MRG.3IMERG.19980512-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980512-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76405 (75K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980512-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  74.61K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:31:28 (2.46 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980512-S000000-E235959.V07B.nc4.SUB.nc4’ saved [76405/76405]
#
# --2025-02-25 16:31:28--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F05%2F3B-DAY.MS.MRG.3IMERG.19980513-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980513-S000000-E235959.V07B.nc4.SUB.nc4
# connected. to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443...
# HTTP request sent, awaiting response... 200 OK
# Length: 94929 (93K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980513-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  92.70K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:31:31 (3.10 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980513-S000000-E235959.V07B.nc4.SUB.nc4’ saved [94929/94929]
#
# --2025-02-25 16:31:31--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F05%2F3B-DAY.MS.MRG.3IMERG.19980514-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980514-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88910 (87K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980514-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  86.83K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:31:33 (2.87 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980514-S000000-E235959.V07B.nc4.SUB.nc4’ saved [88910/88910]
#
# --2025-02-25 16:31:33--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F05%2F3B-DAY.MS.MRG.3IMERG.19980515-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980515-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88596 (87K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980515-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  86.52K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:31:35 (2.83 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980515-S000000-E235959.V07B.nc4.SUB.nc4’ saved [88596/88596]
#
# --2025-02-25 16:31:35--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F05%2F3B-DAY.MS.MRG.3IMERG.19980516-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980516-S000000-E235959.V07B.nc4.SUB.nc4
# connected. to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443...
# HTTP request sent, awaiting response... 200 OK
# Length: 99722 (97K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980516-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  97.38K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:31:37 (3.17 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980516-S000000-E235959.V07B.nc4.SUB.nc4’ saved [99722/99722]
#
# --2025-02-25 16:31:37--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F05%2F3B-DAY.MS.MRG.3IMERG.19980517-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980517-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 95340 (93K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980517-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  93.11K  --.-KB/s    in 0.03s
#
# 2025-02-25 16:31:39 (3.06 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980517-S000000-E235959.V07B.nc4.SUB.nc4’ saved [95340/95340]
#
# --2025-02-25 16:31:39--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F05%2F3B-DAY.MS.MRG.3IMERG.19980518-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980518-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 95964 (94K) [application/octet-stream]
# Saving to: ‘./data/3B-DAY.MS.MRG.3IMERG.19980518-S000000-E235959.V07B.nc4.SUB.nc4’
#
# 3B-DAY.MS.MRG.3IMER 100%[===================>]  93.71K  --.-KB/s    in 0.04s
#
# 2025-02-25 16:31:42 (2.06 MB/s) - ‘./data/3B-DAY.MS.MRG.3IMERG.19980518-S000000-E235959.V07B.nc4.SUB.nc4’ saved [95964/95964]
#
# --2025-02-25 16:31:42--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDF.07%2F1998%2F05%2F3B-DAY.MS.MRG.3IMERG.19980519-S000000-E235959.V07B.nc4&BBOX=4.3%2C-3.8%2C11.6%2C1.8&SERVICE=L34RS_GPM&SHORTNAME=GPM_3IMERGDF&FORMAT=bmM0Lw&VERSION=1.02&DATASET_VERSION=07&LABEL=3B-DAY.MS.MRG.3IMERG.19980519-S000000-E235959.V07B.nc4.SUB.nc4
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response...

# %%
#Test any one file
import netCDF4 as nc4
dta = nc4.Dataset('./data/3B-DAY.MS.MRG.3IMERG.19980101-S000000-E235959.V07B.nc4.SUB.nc4')
#print(dta)
I = dta.variables['precipitation'][0,:].data #more smooth
print(I.shape)
I = dta.variables['lat'][:]
print(I)
# Out:
# (56, 73)
# [ 4.35  4.45  4.55  4.65  4.75  4.85  4.95  5.05  5.15  5.25  5.35  5.45
#   5.55  5.65  5.75  5.85  5.95  6.05  6.15  6.25  6.35  6.45  6.55  6.65
#   6.75  6.85  6.95  7.05  7.15  7.25  7.35  7.45  7.55  7.65  7.75  7.85
#   7.95  8.05  8.15  8.25  8.35  8.45  8.55  8.65  8.75  8.85  8.95  9.05
#   9.15  9.25  9.35  9.45  9.55  9.65  9.75  9.85  9.95 10.05 10.15 10.25
#  10.35 10.45 10.55 10.65 10.75 10.85 10.95 11.05 11.15 11.25 11.35 11.45
#  11.55]
